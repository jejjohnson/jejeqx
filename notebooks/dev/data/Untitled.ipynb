# %%
from intake import open_catalog
import zarr

# %%
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean/altimetry.yaml")
list(cat)
# Out:
# ['al',
#  'alg',
#  'c2',
#  'e1',
#  'e1g',
#  'e2',
#  'en',
#  'enn',
#  'g2',
#  'h2',
#  'j1',
#  'j1g',
#  'j1n',
#  'j2',
#  'j2g',
#  'j2n',
#  'j3',
#  's3a',
#  's3b',
#  'tp',
#  'tpn']

# %%
dssat  = cat["al"].to_dask()
dssat
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dssat  = cat["al"].to_dask()
#       2 dssat
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake_xarray/base.py:69, in DataSourceMixin.to_dask(self)
#      67 def to_dask(self):
#      68     """Return xarray object where variables are dask arrays"""
# ---> 69     return self.read_chunked()
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake_xarray/base.py:44, in DataSourceMixin.read_chunked(self)
#      42 def read_chunked(self):
#      43     """Return xarray object (which will have chunks)"""
# ---> 44     self._load_metadata()
#      45     return self._ds
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake/source/base.py:279, in DataSourceBase._load_metadata(self)
#     277 """load metadata only if needed"""
#     278 if self._schema is None:
# --> 279     self._schema = self._get_schema()
#     280     self.dtype = self._schema.dtype
#     281     self.shape = self._schema.shape
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake_xarray/base.py:18, in DataSourceMixin._get_schema(self)
#      15 self.urlpath = self._get_cache(self.urlpath)[0]
#      17 if self._ds is None:
# ---> 18     self._open_dataset()
#      20     metadata = {
#      21         'dims': dict(self._ds.dims),
#      22         'data_vars': {k: list(self._ds[k].coords)
#      23                       for k in self._ds.data_vars.keys()},
#      24         'coords': tuple(self._ds.coords.keys()),
#      25     }
#      26     if getattr(self, 'on_server', False):
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake_xarray/xzarr.py:46, in ZarrSource._open_dataset(self)
#      44     self._ds = xr.open_mfdataset(self.urlpath, **kw)
#      45 else:
# ---> 46     self._ds = xr.open_dataset(self.urlpath, **kw)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/xarray/backends/api.py:526, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     514 decoders = _resolve_decoders_kwargs(
#     515     decode_cf,
#     516     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     522     decode_coords=decode_coords,
#     523 )
#     525 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 526 backend_ds = backend.open_dataset(
#     527     filename_or_obj,
#     528     drop_variables=drop_variables,
#     529     **decoders,
#     530     **kwargs,
#     531 )
#     532 ds = _dataset_from_backend_dataset(
#     533     backend_ds,
#     534     filename_or_obj,
#    (...)
#     542     **kwargs,
#     543 )
#     544 return ds
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/xarray/backends/zarr.py:891, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, stacklevel, zarr_version)
#     871 def open_dataset(
#     872     self,
#     873     filename_or_obj,
#    (...)
#     888     zarr_version=None,
#     889 ):
#     890     filename_or_obj = _normalize_path(filename_or_obj)
# --> 891     store = ZarrStore.open_group(
#     892         filename_or_obj,
#     893         group=group,
#     894         mode=mode,
#     895         synchronizer=synchronizer,
#     896         consolidated=consolidated,
#     897         consolidate_on_close=False,
#     898         chunk_store=chunk_store,
#     899         storage_options=storage_options,
#     900         stacklevel=stacklevel + 1,
#     901         zarr_version=zarr_version,
#     902     )
#     904     store_entrypoint = StoreBackendEntrypoint()
#     905     with close_on_error(store):
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/xarray/backends/zarr.py:428, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, stacklevel, zarr_version)
#     425             raise FileNotFoundError(f"No such file or directory: '{store}'")
#     426 elif consolidated:
#     427     # TODO: an option to pass the metadata_key keyword
# --> 428     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#     429 else:
#     430     zarr_group = zarr.open_group(store, **open_kwargs)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/zarr/convenience.py:1299, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1296         metadata_key = 'meta/root/consolidated/' + metadata_key
#    1298 # setup metadata store
# -> 1299 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1301 # pass through
#    1302 chunk_store = kwargs.pop('chunk_store', None) or store
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/zarr/storage.py:2886, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    2883 self.store = Store._ensure_store(store)
#    2885 # retrieve consolidated metadata
# -> 2886 meta = json_loads(self.store[metadata_key])
#    2888 # check format of consolidated metadata
#    2889 consolidated_format = meta.get('zarr_consolidated_format', None)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/zarr/storage.py:1393, in FSStore.__getitem__(self, key)
#    1391 key = self._normalize_key(key)
#    1392 try:
# -> 1393     return self.map[key]
#    1394 except self.exceptions as e:
#    1395     raise KeyError(key) from e
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/mapping.py:143, in FSMap.__getitem__(self, key, default)
#     141 k = self._key_to_str(key)
#     142 try:
# --> 143     result = self.fs.cat(k)
#     144 except self.missing_exceptions:
#     145     if default is not None:
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/asyn.py:115, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def wrapper(*args, **kwargs):
#     114     self = obj or args[0]
# --> 115     return sync(self.loop, func, *args, **kwargs)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/asyn.py:100, in sync(loop, func, timeout, *args, **kwargs)
#      98     raise FSTimeoutError from return_result
#      99 elif isinstance(return_result, BaseException):
# --> 100     raise return_result
#     101 else:
#     102     return return_result
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/asyn.py:55, in _runner(event, coro, result, timeout)
#      53     coro = asyncio.wait_for(coro, timeout=timeout)
#      54 try:
# ---> 55     result[0] = await coro
#      56 except Exception as ex:
#      57     result[0] = ex
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/asyn.py:414, in AsyncFileSystem._cat(self, path, recursive, on_error, batch_size, **kwargs)
#     412     ex = next(filter(is_exception, out), False)
#     413     if ex:
# --> 414         raise ex
#     415 if (
#     416     len(paths) > 1
#     417     or isinstance(path, list)
#     418     or paths[0] != self._strip_protocol(path)
#     419 ):
#     420     return {
#     421         k: v
#     422         for k, v in zip(paths, out)
#     423         if on_error != "omit" or not is_exception(v)
#     424     }
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/asyncio/tasks.py:442, in wait_for(fut, timeout, loop)
#     437     warnings.warn("The loop argument is deprecated since Python 3.8, "
#     438                   "and scheduled for removal in Python 3.10.",
#     439                   DeprecationWarning, stacklevel=2)
#     441 if timeout is None:
# --> 442     return await fut
#     444 if timeout <= 0:
#     445     fut = ensure_future(fut, loop=loop)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/core.py:877, in GCSFileSystem._cat_file(self, path, start, end, **kwargs)
#     875 else:
#     876     head = {}
# --> 877 headers, out = await self._call("GET", u2, headers=head)
#     878 return out
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/core.py:429, in GCSFileSystem._call(self, method, path, json_out, info_out, *args, **kwargs)
#     425 async def _call(
#     426     self, method, path, *args, json_out=False, info_out=False, **kwargs
#     427 ):
#     428     logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
# --> 429     status, headers, info, contents = await self._request(
#     430         method, path, *args, **kwargs
#     431     )
#     432     if json_out:
#     433         return json.loads(contents)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/decorator.py:221, in decorate.<locals>.fun(*args, **kw)
#     219 if not kwsyntax:
#     220     args, kw = fix(args, kw, sig)
# --> 221 return await caller(func, *(extras + args), **kw)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/retry.py:114, in retry_request(func, retries, *args, **kwargs)
#     112     if retry > 0:
#     113         await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 114     return await func(*args, **kwargs)
#     115 except (
#     116     HttpError,
#     117     requests.exceptions.RequestException,
#    (...)
#     120     aiohttp.client_exceptions.ClientError,
#     121 ) as e:
#     122     if (
#     123         isinstance(e, HttpError)
#     124         and e.code == 400
#     125         and "requester pays" in e.message
#     126     ):
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/core.py:422, in GCSFileSystem._request(self, method, path, headers, json, data, *args, **kwargs)
#     419 info = r.request_info  # for debug only
#     420 contents = await r.read()
# --> 422 validate_response(status, contents, path, args)
#     423 return status, headers, info, contents
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/retry.py:99, in validate_response(status, content, path, args)
#      97     raise requests.exceptions.ProxyError()
#      98 elif "invalid" in str(msg):
# ---> 99     raise ValueError(f"Bad Request: {path}\n{msg}")
#     100 elif error:
#     101     raise HttpError(error)
#
# ValueError: Bad Request: https://storage.googleapis.com/download/storage/v1/b/pangeo-cnes/o/alti%2Fal%2F.zmetadata?alt=media
# User project specified in the request is invalid.

# %%
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean/MEOM-NEMO.yaml")
list(cat)
# Out:
# ['NATL60_coord',
#  'NATL60_horizontal_grid',
#  'NATL60_vertical_grid',
#  'NATL60_SSH',
#  'NATL60_SSH_1',
#  'NATL60_SSU',
#  'NATL60_SSV',
#  'eNATL60_grid',
#  'eNATL60_BLBT02_SSH',
#  'eNATL60_BLBT02_SSU',
#  'eNATL60_BLBT02_SSV',
#  'eNATL60_BLB002_SSU',
#  'eNATL60_BLB002_SSV']

# %%
ds  = cat["NATL60_SSH"].to_dask()
ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds  = cat["NATL60_SSH"].to_dask()
#       2 ds
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake_xarray/base.py:69, in DataSourceMixin.to_dask(self)
#      67 def to_dask(self):
#      68     """Return xarray object where variables are dask arrays"""
# ---> 69     return self.read_chunked()
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake_xarray/base.py:44, in DataSourceMixin.read_chunked(self)
#      42 def read_chunked(self):
#      43     """Return xarray object (which will have chunks)"""
# ---> 44     self._load_metadata()
#      45     return self._ds
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake/source/base.py:279, in DataSourceBase._load_metadata(self)
#     277 """load metadata only if needed"""
#     278 if self._schema is None:
# --> 279     self._schema = self._get_schema()
#     280     self.dtype = self._schema.dtype
#     281     self.shape = self._schema.shape
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake_xarray/base.py:18, in DataSourceMixin._get_schema(self)
#      15 self.urlpath = self._get_cache(self.urlpath)[0]
#      17 if self._ds is None:
# ---> 18     self._open_dataset()
#      20     metadata = {
#      21         'dims': dict(self._ds.dims),
#      22         'data_vars': {k: list(self._ds[k].coords)
#      23                       for k in self._ds.data_vars.keys()},
#      24         'coords': tuple(self._ds.coords.keys()),
#      25     }
#      26     if getattr(self, 'on_server', False):
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/intake_xarray/xzarr.py:46, in ZarrSource._open_dataset(self)
#      44     self._ds = xr.open_mfdataset(self.urlpath, **kw)
#      45 else:
# ---> 46     self._ds = xr.open_dataset(self.urlpath, **kw)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/xarray/backends/api.py:526, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     514 decoders = _resolve_decoders_kwargs(
#     515     decode_cf,
#     516     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     522     decode_coords=decode_coords,
#     523 )
#     525 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 526 backend_ds = backend.open_dataset(
#     527     filename_or_obj,
#     528     drop_variables=drop_variables,
#     529     **decoders,
#     530     **kwargs,
#     531 )
#     532 ds = _dataset_from_backend_dataset(
#     533     backend_ds,
#     534     filename_or_obj,
#    (...)
#     542     **kwargs,
#     543 )
#     544 return ds
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/xarray/backends/zarr.py:891, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, stacklevel, zarr_version)
#     871 def open_dataset(
#     872     self,
#     873     filename_or_obj,
#    (...)
#     888     zarr_version=None,
#     889 ):
#     890     filename_or_obj = _normalize_path(filename_or_obj)
# --> 891     store = ZarrStore.open_group(
#     892         filename_or_obj,
#     893         group=group,
#     894         mode=mode,
#     895         synchronizer=synchronizer,
#     896         consolidated=consolidated,
#     897         consolidate_on_close=False,
#     898         chunk_store=chunk_store,
#     899         storage_options=storage_options,
#     900         stacklevel=stacklevel + 1,
#     901         zarr_version=zarr_version,
#     902     )
#     904     store_entrypoint = StoreBackendEntrypoint()
#     905     with close_on_error(store):
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/xarray/backends/zarr.py:428, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, stacklevel, zarr_version)
#     425             raise FileNotFoundError(f"No such file or directory: '{store}'")
#     426 elif consolidated:
#     427     # TODO: an option to pass the metadata_key keyword
# --> 428     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#     429 else:
#     430     zarr_group = zarr.open_group(store, **open_kwargs)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/zarr/convenience.py:1299, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1296         metadata_key = 'meta/root/consolidated/' + metadata_key
#    1298 # setup metadata store
# -> 1299 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1301 # pass through
#    1302 chunk_store = kwargs.pop('chunk_store', None) or store
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/zarr/storage.py:2886, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    2883 self.store = Store._ensure_store(store)
#    2885 # retrieve consolidated metadata
# -> 2886 meta = json_loads(self.store[metadata_key])
#    2888 # check format of consolidated metadata
#    2889 consolidated_format = meta.get('zarr_consolidated_format', None)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/zarr/storage.py:1393, in FSStore.__getitem__(self, key)
#    1391 key = self._normalize_key(key)
#    1392 try:
# -> 1393     return self.map[key]
#    1394 except self.exceptions as e:
#    1395     raise KeyError(key) from e
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/mapping.py:143, in FSMap.__getitem__(self, key, default)
#     141 k = self._key_to_str(key)
#     142 try:
# --> 143     result = self.fs.cat(k)
#     144 except self.missing_exceptions:
#     145     if default is not None:
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/asyn.py:115, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def wrapper(*args, **kwargs):
#     114     self = obj or args[0]
# --> 115     return sync(self.loop, func, *args, **kwargs)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/asyn.py:100, in sync(loop, func, timeout, *args, **kwargs)
#      98     raise FSTimeoutError from return_result
#      99 elif isinstance(return_result, BaseException):
# --> 100     raise return_result
#     101 else:
#     102     return return_result
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/asyn.py:55, in _runner(event, coro, result, timeout)
#      53     coro = asyncio.wait_for(coro, timeout=timeout)
#      54 try:
# ---> 55     result[0] = await coro
#      56 except Exception as ex:
#      57     result[0] = ex
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/fsspec/asyn.py:414, in AsyncFileSystem._cat(self, path, recursive, on_error, batch_size, **kwargs)
#     412     ex = next(filter(is_exception, out), False)
#     413     if ex:
# --> 414         raise ex
#     415 if (
#     416     len(paths) > 1
#     417     or isinstance(path, list)
#     418     or paths[0] != self._strip_protocol(path)
#     419 ):
#     420     return {
#     421         k: v
#     422         for k, v in zip(paths, out)
#     423         if on_error != "omit" or not is_exception(v)
#     424     }
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/asyncio/tasks.py:442, in wait_for(fut, timeout, loop)
#     437     warnings.warn("The loop argument is deprecated since Python 3.8, "
#     438                   "and scheduled for removal in Python 3.10.",
#     439                   DeprecationWarning, stacklevel=2)
#     441 if timeout is None:
# --> 442     return await fut
#     444 if timeout <= 0:
#     445     fut = ensure_future(fut, loop=loop)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/core.py:877, in GCSFileSystem._cat_file(self, path, start, end, **kwargs)
#     875 else:
#     876     head = {}
# --> 877 headers, out = await self._call("GET", u2, headers=head)
#     878 return out
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/core.py:429, in GCSFileSystem._call(self, method, path, json_out, info_out, *args, **kwargs)
#     425 async def _call(
#     426     self, method, path, *args, json_out=False, info_out=False, **kwargs
#     427 ):
#     428     logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
# --> 429     status, headers, info, contents = await self._request(
#     430         method, path, *args, **kwargs
#     431     )
#     432     if json_out:
#     433         return json.loads(contents)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/decorator.py:221, in decorate.<locals>.fun(*args, **kw)
#     219 if not kwsyntax:
#     220     args, kw = fix(args, kw, sig)
# --> 221 return await caller(func, *(extras + args), **kw)
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/retry.py:114, in retry_request(func, retries, *args, **kwargs)
#     112     if retry > 0:
#     113         await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 114     return await func(*args, **kwargs)
#     115 except (
#     116     HttpError,
#     117     requests.exceptions.RequestException,
#    (...)
#     120     aiohttp.client_exceptions.ClientError,
#     121 ) as e:
#     122     if (
#     123         isinstance(e, HttpError)
#     124         and e.code == 400
#     125         and "requester pays" in e.message
#     126     ):
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/core.py:422, in GCSFileSystem._request(self, method, path, headers, json, data, *args, **kwargs)
#     419 info = r.request_info  # for debug only
#     420 contents = await r.read()
# --> 422 validate_response(status, contents, path, args)
#     423 return status, headers, info, contents
#
# File ~/miniconda3/envs/jax_eo_py310/lib/python3.9/site-packages/gcsfs/retry.py:99, in validate_response(status, content, path, args)
#      97     raise requests.exceptions.ProxyError()
#      98 elif "invalid" in str(msg):
# ---> 99     raise ValueError(f"Bad Request: {path}\n{msg}")
#     100 elif error:
#     101     raise HttpError(error)
#
# ValueError: Bad Request: https://storage.googleapis.com/download/storage/v1/b/pangeo-meom/o/NATL60-CJM165-SSH-1h-2D%2F.zmetadata?alt=media
# User project specified in the request is invalid.
